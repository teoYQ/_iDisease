# %%
import os
import numpy as np
import pandas as pd 
import random
import cv2
import matplotlib.pyplot as plt

import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Dense, Flatten, Dropout, BatchNormalization
from tensorflow.keras.layers import Conv2D, SeparableConv2D, MaxPool2D, LeakyReLU, Activation, ZeroPadding2D, Add,add,AveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.utils import plot_model
import imgaug as ia
import imgaug.augmenters as iaa


from os import listdir
from os.path import isfile, join
from PIL import Image
import glob


seed = 2019
np.random.seed(seed)
# %matplotlib inline

# %%
tf.__version__
# Out:
# '2.1.0'

# %%
dirname = ''
train_path = os.path.join(dirname, 'OCT2017/train')
train_normal_pth = os.path.join(train_path, 'NORMAL')
train_dme_pth = os.path.join(train_path, 'DME')
train_drusen_pth = os.path.join(train_path, 'DRUSEN')
train_cnv_pth = os.path.join(train_path, 'CNV')
    
test_path = os.path.join(dirname, 'OCT2017/test')
test_normal_pth = os.path.join(test_path, 'NORMAL')
test_dme_pth = os.path.join(test_path, 'DME')
test_drusen_pth = os.path.join(test_path, 'DRUSEN')
test_cnv_pth = os.path.join(test_path, 'CNV')
    
val_path = os.path.join(dirname, 'OCT2017/val')
val_normal_pth = os.path.join(val_path, 'NORMAL')
val_dme_pth = os.path.join(val_path, 'DME')
val_drusen_pth = os.path.join(val_path, 'DRUSEN')
val_cnv_pth = os.path.join(val_path, 'CNV')

# %%
def plot_imgs(item_dir, num_imgs=4):
    all_item_dirs = os.listdir(item_dir)
    item_files = [os.path.join(item_dir, file) for file in all_item_dirs][:num_imgs]

    plt.figure(figsize=(16, 16))
    for idx, img_path in enumerate(item_files):
        plt.subplot(1, 4, idx+1)

        img = cv2.imread(img_path)
        #img_eq = cv2.equalizeHist(img)

        plt.imshow(img)

    plt.tight_layout()

# %%
plot_imgs(test_normal_pth)

# %%
plot_imgs(test_normal_pth)

# %%
def Images_details_Print_data(data, path):
    print(" ====== Images in: ", path)    
    for k, v in data.items():
        print("%s:\t%s" % (k, v))

def Images_details(path):
    files = [f for f in glob.glob(path + "**/*.*", recursive=True)]
    data = {}
    data['images_count'] = len(files)
    data['min_width'] = 10**100  # No image will be bigger than that
    data['max_width'] = 0
    data['min_height'] = 10**100  # No image will be bigger than that
    data['max_height'] = 0


    for f in files:
        im = Image.open(f)
        width, height = im.size
        data['min_width'] = min(width, data['min_width'])
        data['min_height'] = min(height, data['min_height'])
        data['max_width'] = max(width, data['max_height'])
        
        data['max_height'] = max(height, data['max_height'])

    Images_details_Print_data(data, path)

# %%
Images_details(train_normal_pth)
Images_details(train_dme_pth)
Images_details(train_drusen_pth)
Images_details(train_cnv_pth)

# %%
input_path = "OCT2017/"

for _set in ['train', 'test', 'val']:
    normal = len(os.listdir(input_path + _set + '/NORMAL'))
    dme = len(os.listdir(input_path + _set + '/DME'))
    drusen = len(os.listdir(input_path + _set + '/DRUSEN'))
    cnv = len(os.listdir(input_path + _set + '/CNV'))
    print('{}, Normal images: {}, DME images: {}, DRUSEN images: {}, CNV images: {}'.format(_set, normal, dme, drusen, cnv))
# Out:
# train, Normal images: 20798, DME images: 18057, DRUSEN images: 13448, CNV images: 30509
# test, Normal images: 5518, DME images: 2402, DRUSEN images: 1962, CNV images: 6706
# val, Normal images: 136, DME images: 136, DRUSEN images: 136, CNV images: 136

# %%
import imgaug as ia
import imgaug.augmenters as iaa

seq = iaa.Sequential([
        iaa.Fliplr(0.5),
        iaa.Flipud(0.5),
        iaa.Invert(0.2),
        #iaa.Rotate((-45, 45)),
        #iaa.GaussianBlur(sigma=(0, 3.0)) 
        #iaa.Alpha((0.0, 1.0), iaa.AllChannelsHistogramEqualization())
        # blur images with a sigma of 0 to 3.0
    ])
def augment(img):
        seq_det = seq.to_deterministic()
        
        aug_image = seq_det.augment_image(img)
        return aug_image
    
def process_data(img_dims, batch_size):
    # Data generation objects
    train_datagen = ImageDataGenerator(
        rescale = 1./255,
      #  featurewise_center=True,
      #  featurewise_std_normalization=True,
        zoom_range = 0.3,
        horizontal_flip = True
        #preprocessing_function = augment 
    )
    
    test_datagen = ImageDataGenerator(
      #  featurewise_center=True,
      #  featurewise_std_normalization=True,
        rescale=1./255)
    
    # This is fed to the network in the specified batch sizes and image dimensions
    train_gen = train_datagen.flow_from_directory(
    directory = train_path, 
    target_size = (img_dims, img_dims), 
    batch_size = batch_size, 
    class_mode = 'categorical', 
    shuffle=True)

    test_gen = test_datagen.flow_from_directory(
    directory=val_path, 
    target_size=(img_dims, img_dims), 
    batch_size=batch_size, 
    class_mode='categorical', 
    shuffle=True)
    
    return train_gen, test_gen

# %%
PARAMS = {'img_dims': 160,
          'epochs': 35,
          'batch_size': 32,
          'optimizer': 'adam',
          'loss': 'categorical_crossentropy',
          'metrics': 'categorical_accuracy',
          }

# %%
#train_gen, test_gen, test_data, test_labels = process_data(PARAMS['img_dims'], PARAMS['batch_size'])

config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.compat.v1.InteractiveSession(config=config)
USE_GPU = True

if USE_GPU:
    device = '/device:GPU:0'
else:
    device = '/cpu:0'
# Constant to control how often we print when training models

# Constant to control how often we print when training models
print_every = 100

train_gen, test_gen = process_data(PARAMS['img_dims'], PARAMS['batch_size'])
inputs = Input(shape=(PARAMS['img_dims'], PARAMS['img_dims'], 3))
# Out:
# Found 82811 images belonging to 4 classes.
# Found 544 images belonging to 4 classes.

# %%
def identity_block(X, f, filters):

    
    # Retrieve Filters
    F1, F2, F3 = filters
    
    F1 = F1 // 4 
    F2 = F2 // 4
    F3 = F3 // 4
    
    # Save the input value
    X_shortcut = X
    
    # First component of main path
    X1 = Conv2D(filters = F1, kernel_size = (1, 1), strides = (1,1), padding = 'valid')(X)
    X1 = BatchNormalization(axis = 3)(X1)
    X1 = Activation('relu')(X1)
    
    X2 = Conv2D(filters = F1, kernel_size = (1, 1), strides = (1,1), padding = 'valid')(X)
    X2 = BatchNormalization(axis = 3)(X2)
    X2 = Activation('relu')(X2)
    
    X3 = Conv2D(filters=F1, kernel_size=(1, 1), strides=(1, 1), padding='valid')(X)
    X3 = BatchNormalization(axis=3)(X3)
    X3 = Activation('relu')(X3)
    
    
    # Second component of main path
    X1 = Conv2D(filters = F2, kernel_size = (f, f), strides = (1, 1), padding = 'same')(X1)
    X1 = BatchNormalization(axis = 3)(X1)
    X1 = Activation('relu')(X1)
    
    X2 = Conv2D(filters = F2, kernel_size = (f, f), strides = (1, 1), padding = 'same')(X2)
    X2 = BatchNormalization(axis = 3,)(X2)
    X2 = Activation('relu')(X2)
    
    X3 = Conv2D(filters=F2, kernel_size=(f, f), strides=(1, 1), padding='same')(X3)
    X3 = BatchNormalization(axis=3)(X3)
    X3 = Activation('relu')(X3)
    
    
    # Third component of main path 
    X1 = Conv2D(filters = F3, kernel_size = (1, 1), strides = (1, 1), padding = 'valid')(X1)
    X1 = BatchNormalization(axis = 3)(X1)
    
    X2 = Conv2D(filters = F3, kernel_size = (1, 1), strides = (1, 1), padding = 'valid')(X2)
    X2 = BatchNormalization(axis = 3)(X2)
    
    X3 = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='valid')(X3)
    X3 = BatchNormalization(axis=3)(X3)

    # Final step: Add shortcut value to main path, and pass it through a RELU activation
    X = Add()([X1, X2,X3])
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)
    
    return X

# %%
def convolutional_block(X, f, filters, s=2):


    # Retrieve Filters
    F1, F2, F3 = filters
    
    F1 = F1 // 4
    F2 = F2 // 4
    F3 = F3 // 4

    # Save the input value
    X_shortcut = X

    ##### MAIN PATH #####
    # First component of main path 
    X1 = Conv2D(filters=F1, kernel_size=(1, 1), strides=(s, s), padding='valid')(X)
    X1 = BatchNormalization(axis=3)(X1)
    X1 = Activation('relu')(X1)
    
    X2 = Conv2D(filters=F1, kernel_size=(1, 1), strides=(s, s), padding='valid')(X)
    X2 = BatchNormalization(axis=3)(X2)
    X2 = Activation('relu')(X2)

    X3 = Conv2D(filters=F1, kernel_size=(1, 1), strides=(s, s), padding='valid')(X)
    X3 = BatchNormalization(axis=3)(X3)
    X3 = Activation('relu')(X3)

    # Second component of main path
    X1 = Conv2D(filters=F2, kernel_size=(f, f), strides=(1, 1), padding='same')(X1)
    X1 = BatchNormalization(axis=3)(X1)
    X1 = Activation('relu')(X1)
    
    X2 = Conv2D(filters=F2, kernel_size=(f, f), strides=(1, 1), padding='same')(X2)
    X2 = BatchNormalization(axis=3)(X2)
    X2 = Activation('relu')(X2)
    
    X3 = Conv2D(filters=F2, kernel_size=(f, f), strides=(1, 1), padding='same')(X3)
    X3 = BatchNormalization(axis=3)(X3)
    X3 = Activation('relu')(X3)
    

    # Third component of main path
    X1 = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='valid')(X1)
    X1 = BatchNormalization(axis=3)(X1)
    
    X2 = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='valid')(X2)
    X2 = BatchNormalization(axis=3)(X2)
    
    X3 = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='valid')(X3)
    X3 = BatchNormalization(axis=3)(X3)


    X = Add()([X1, X2,X3])
    
    ##### SHORTCUT PATH #### 
    X_shortcut = Conv2D(filters=F3, kernel_size=(1, 1), strides=(s, s), padding='valid')(X_shortcut)
    X_shortcut = BatchNormalization(axis=3)(X_shortcut)

    # Final step: Add shortcut value to main path, and pass it through a RELU activation
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)

    return X

# %%
filters= [(64, 64, 256),(128, 128, 512),(256, 256, 1024),(512, 512, 2048)]

X = ZeroPadding2D((3,3))(inputs)
# First conv block
X = Conv2D(64, (7, 7), strides = (2, 2), name = 'conv1')(X)
X = BatchNormalization(axis = 3, name = 'bn_conv1')(X)
X = Activation('relu')(X)
X = MaxPool2D((3, 3), strides=(2, 2))(X)


# Stage 2
X = convolutional_block(X, f = 3, filters = filters[0] )
X = identity_block(X, 3,filters[0])
X = identity_block(X, 3,filters[0])
# Stage 3
X = convolutional_block(X, f=3, filters=filters[1])
X = identity_block(X, 3, filters[1])
X = identity_block(X, 3, filters[1])
X = identity_block(X, 3, filters[1])

# Stage 4
X = convolutional_block(X, f=3, filters=filters[2])
X = identity_block(X, 3, filters[2])
X = identity_block(X, 3, filters[2])
X = identity_block(X, 3, filters[2])
X = identity_block(X, 3, filters[2])
X = identity_block(X, 3, filters[2])

# Stage 5
X = convolutional_block(X, f=3, filters=filters[3])
X = identity_block(X, 3, filters[3])
X = identity_block(X, 3,filters[3])

# Average pool, flatten and dense to 4 
X = AveragePooling2D(pool_size=(2,2), padding='same')(X)
X = Flatten()(X)
X = Dense(4, activation='softmax')(X)

# Creating model and compiling
model = Model(inputs=inputs, outputs=X)
model.compile(optimizer=PARAMS['optimizer'], loss=PARAMS['loss'], metrics=["categorical_accuracy"])

# %%
from sklearn.utils import class_weight
y_train = train_gen.classes

class_weights = class_weight.compute_class_weight('balanced', np.unique(y_train), y_train)
class_weights = dict(enumerate(class_weights))

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 160, 160, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 166, 166, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 80, 80, 64)   9472        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 80, 80, 64)   256         conv1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 80, 80, 64)   0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 39, 39, 64)   0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 20, 20, 16)   1040        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 20, 20, 16)   1040        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 20, 20, 16)   1040        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 20, 20, 16)   64          conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 20, 20, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 20, 20, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 20, 20, 16)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 20, 20, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 20, 20, 16)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 20, 20, 16)   2320        activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 20, 20, 16)   2320        activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 20, 20, 16)   2320        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 20, 20, 16)   64          conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 20, 20, 16)   64          conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 20, 20, 16)   64          conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 20, 20, 16)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 20, 20, 16)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 20, 20, 16)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 20, 20, 64)   1088        activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 20, 20, 64)   1088        activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 20, 20, 64)   1088        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 20, 20, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 20, 20, 64)   256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 20, 20, 64)   256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 20, 20, 64)   4160        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 20, 20, 64)   0           batch_normalization_6[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 20, 20, 64)   256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 20, 20, 64)   0           add[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 20, 20, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 20, 20, 16)   1040        activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 20, 20, 16)   1040        activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 20, 20, 16)   1040        activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 20, 20, 16)   64          conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 20, 20, 16)   64          conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 20, 20, 16)   64          conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 20, 20, 16)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 20, 20, 16)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 20, 20, 16)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 20, 20, 16)   2320        activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 20, 20, 16)   2320        activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 20, 20, 16)   2320        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 20, 20, 16)   64          conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 20, 20, 16)   64          conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 20, 20, 16)   64          conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 20, 20, 16)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 20, 20, 16)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 20, 20, 16)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 20, 20, 64)   1088        activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 20, 20, 64)   1088        activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 20, 20, 64)   1088        activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 20, 20, 64)   256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 20, 20, 64)   256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 20, 20, 64)   256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 20, 20, 64)   0           batch_normalization_16[0][0]
#                                                                  batch_normalization_17[0][0]
#                                                                  batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 20, 20, 64)   0           add_2[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 20, 20, 64)   0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 20, 20, 16)   1040        activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 20, 20, 16)   1040        activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 20, 20, 16)   1040        activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 20, 20, 16)   64          conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 20, 20, 16)   64          conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 20, 20, 16)   64          conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 20, 20, 16)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 20, 20, 16)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 20, 20, 16)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 20, 20, 16)   2320        activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 20, 20, 16)   2320        activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 20, 20, 16)   2320        activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 20, 20, 16)   64          conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 20, 20, 16)   64          conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 20, 20, 16)   64          conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 20, 20, 16)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 20, 20, 16)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 20, 20, 16)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 20, 20, 64)   1088        activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 20, 20, 64)   1088        activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 20, 20, 64)   1088        activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 20, 20, 64)   256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 20, 20, 64)   256         conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 20, 20, 64)   256         conv2d_27[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 20, 20, 64)   0           batch_normalization_25[0][0]
#                                                                  batch_normalization_26[0][0]
#                                                                  batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 20, 20, 64)   0           add_4[0][0]
#                                                                  activation_14[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 20, 20, 64)   0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 10, 10, 32)   2080        activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 10, 10, 32)   2080        activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 10, 10, 32)   2080        activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 10, 10, 32)   128         conv2d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 10, 10, 32)   128         conv2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 10, 10, 32)   128         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 10, 10, 32)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 10, 10, 32)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 10, 10, 32)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 10, 10, 32)   9248        activation_22[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 10, 10, 32)   9248        activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 10, 10, 32)   9248        activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 10, 10, 32)   128         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 10, 10, 32)   128         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 10, 10, 32)   128         conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 10, 10, 32)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 10, 10, 32)   0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 10, 10, 32)   0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 10, 10, 128)  4224        activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 10, 10, 128)  4224        activation_26[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 10, 10, 128)  4224        activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 10, 10, 128)  512         conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 10, 10, 128)  512         conv2d_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 10, 10, 128)  512         conv2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 10, 10, 128)  8320        activation_21[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 10, 10, 128)  0           batch_normalization_34[0][0]
#                                                                  batch_normalization_35[0][0]
#                                                                  batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 10, 10, 128)  512         conv2d_37[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 10, 10, 128)  0           add_6[0][0]
#                                                                  batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 10, 10, 128)  0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 10, 10, 32)   4128        activation_28[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 10, 10, 32)   4128        activation_28[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 10, 10, 32)   4128        activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 10, 10, 32)   128         conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 10, 10, 32)   128         conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 10, 10, 32)   128         conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 10, 10, 32)   0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 10, 10, 32)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 10, 10, 32)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 10, 10, 32)   9248        activation_29[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 10, 10, 32)   9248        activation_30[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 10, 10, 32)   9248        activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 10, 10, 32)   128         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 10, 10, 32)   128         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 10, 10, 32)   128         conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 10, 10, 32)   0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 10, 10, 32)   0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 10, 10, 32)   0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 10, 10, 128)  4224        activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 10, 10, 128)  4224        activation_33[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 10, 10, 128)  4224        activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 10, 10, 128)  512         conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 10, 10, 128)  512         conv2d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 10, 10, 128)  512         conv2d_46[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 10, 10, 128)  0           batch_normalization_44[0][0]
#                                                                  batch_normalization_45[0][0]
#                                                                  batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 10, 10, 128)  0           add_8[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 10, 10, 128)  0           add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 10, 10, 32)   4128        activation_35[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 10, 10, 32)   4128        activation_35[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 10, 10, 32)   4128        activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 10, 10, 32)   128         conv2d_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 10, 10, 32)   128         conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 10, 10, 32)   128         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 10, 10, 32)   0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 10, 10, 32)   0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 10, 10, 32)   0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 10, 10, 32)   9248        activation_36[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 10, 10, 32)   9248        activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 10, 10, 32)   9248        activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 10, 10, 32)   128         conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 10, 10, 32)   128         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 10, 10, 32)   128         conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 10, 10, 32)   0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 10, 10, 32)   0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 10, 10, 32)   0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 10, 10, 128)  4224        activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 10, 10, 128)  4224        activation_40[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 10, 10, 128)  4224        activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 10, 10, 128)  512         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 10, 10, 128)  512         conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 10, 10, 128)  512         conv2d_55[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 10, 10, 128)  0           batch_normalization_53[0][0]
#                                                                  batch_normalization_54[0][0]
#                                                                  batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 10, 10, 128)  0           add_10[0][0]
#                                                                  activation_35[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 10, 10, 128)  0           add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 10, 10, 32)   4128        activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 10, 10, 32)   4128        activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 10, 10, 32)   4128        activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 10, 10, 32)   128         conv2d_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 10, 10, 32)   128         conv2d_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 10, 10, 32)   128         conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 10, 10, 32)   0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 10, 10, 32)   0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 10, 10, 32)   0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 10, 10, 32)   9248        activation_43[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 10, 10, 32)   9248        activation_44[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 10, 10, 32)   9248        activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 10, 10, 32)   128         conv2d_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 10, 10, 32)   128         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 10, 10, 32)   128         conv2d_61[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 10, 10, 32)   0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 10, 10, 32)   0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 10, 10, 32)   0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 10, 10, 128)  4224        activation_46[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 10, 10, 128)  4224        activation_47[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 10, 10, 128)  4224        activation_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 10, 10, 128)  512         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 10, 10, 128)  512         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 10, 10, 128)  512         conv2d_64[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 10, 10, 128)  0           batch_normalization_62[0][0]
#                                                                  batch_normalization_63[0][0]
#                                                                  batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 10, 10, 128)  0           add_12[0][0]
#                                                                  activation_42[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 10, 10, 128)  0           add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 5, 5, 64)     8256        activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 5, 5, 64)     8256        activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 5, 5, 64)     8256        activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 5, 5, 64)     256         conv2d_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 5, 5, 64)     256         conv2d_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 5, 5, 64)     256         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 5, 5, 64)     0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 5, 5, 64)     0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 5, 5, 64)     0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 5, 5, 64)     36928       activation_50[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 5, 5, 64)     36928       activation_51[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 5, 5, 64)     36928       activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 5, 5, 64)     256         conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 5, 5, 64)     256         conv2d_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 5, 5, 64)     256         conv2d_70[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 5, 5, 64)     0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 5, 5, 64)     0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 5, 5, 64)     0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 5, 5, 256)    16640       activation_53[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 5, 5, 256)    16640       activation_54[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 5, 5, 256)    16640       activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 5, 5, 256)    1024        conv2d_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 5, 5, 256)    1024        conv2d_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 5, 5, 256)    1024        conv2d_73[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 5, 5, 256)    33024       activation_49[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 5, 5, 256)    0           batch_normalization_71[0][0]
#                                                                  batch_normalization_72[0][0]
#                                                                  batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 5, 5, 256)    1024        conv2d_74[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 5, 5, 256)    0           add_14[0][0]
#                                                                  batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 5, 5, 256)    0           add_15[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 5, 5, 64)     16448       activation_56[0][0]
# ...
# conv2d_125 (Conv2D)             (None, 3, 3, 128)    147584      activation_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_123 (BatchN (None, 3, 3, 128)    512         conv2d_123[0][0]
# __________________________________________________________________________________________________
# batch_normalization_124 (BatchN (None, 3, 3, 128)    512         conv2d_124[0][0]
# __________________________________________________________________________________________________
# batch_normalization_125 (BatchN (None, 3, 3, 128)    512         conv2d_125[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 3, 3, 128)    0           batch_normalization_123[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 3, 3, 128)    0           batch_normalization_124[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 3, 3, 128)    0           batch_normalization_125[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 3, 3, 512)    66048       activation_95[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 3, 3, 512)    66048       activation_96[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 3, 3, 512)    66048       activation_97[0][0]
# __________________________________________________________________________________________________
# batch_normalization_126 (BatchN (None, 3, 3, 512)    2048        conv2d_126[0][0]
# __________________________________________________________________________________________________
# batch_normalization_127 (BatchN (None, 3, 3, 512)    2048        conv2d_127[0][0]
# __________________________________________________________________________________________________
# batch_normalization_128 (BatchN (None, 3, 3, 512)    2048        conv2d_128[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 3, 3, 512)    131584      activation_91[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 3, 3, 512)    0           batch_normalization_126[0][0]
#                                                                  batch_normalization_127[0][0]
#                                                                  batch_normalization_128[0][0]
# __________________________________________________________________________________________________
# batch_normalization_129 (BatchN (None, 3, 3, 512)    2048        conv2d_129[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 3, 3, 512)    0           add_26[0][0]
#                                                                  batch_normalization_129[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 3, 3, 512)    0           add_27[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 3, 3, 128)    65664       activation_98[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 3, 3, 128)    65664       activation_98[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 3, 3, 128)    65664       activation_98[0][0]
# __________________________________________________________________________________________________
# batch_normalization_130 (BatchN (None, 3, 3, 128)    512         conv2d_130[0][0]
# __________________________________________________________________________________________________
# batch_normalization_131 (BatchN (None, 3, 3, 128)    512         conv2d_131[0][0]
# __________________________________________________________________________________________________
# batch_normalization_132 (BatchN (None, 3, 3, 128)    512         conv2d_132[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 3, 3, 128)    0           batch_normalization_130[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 3, 3, 128)    0           batch_normalization_131[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 3, 3, 128)    0           batch_normalization_132[0][0]
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, 3, 3, 128)    147584      activation_99[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 3, 3, 128)    147584      activation_100[0][0]
# __________________________________________________________________________________________________
# conv2d_135 (Conv2D)             (None, 3, 3, 128)    147584      activation_101[0][0]
# __________________________________________________________________________________________________
# batch_normalization_133 (BatchN (None, 3, 3, 128)    512         conv2d_133[0][0]
# __________________________________________________________________________________________________
# batch_normalization_134 (BatchN (None, 3, 3, 128)    512         conv2d_134[0][0]
# __________________________________________________________________________________________________
# batch_normalization_135 (BatchN (None, 3, 3, 128)    512         conv2d_135[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 3, 3, 128)    0           batch_normalization_133[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 3, 3, 128)    0           batch_normalization_134[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 3, 3, 128)    0           batch_normalization_135[0][0]
# __________________________________________________________________________________________________
# conv2d_136 (Conv2D)             (None, 3, 3, 512)    66048       activation_102[0][0]
# __________________________________________________________________________________________________
# conv2d_137 (Conv2D)             (None, 3, 3, 512)    66048       activation_103[0][0]
# __________________________________________________________________________________________________
# conv2d_138 (Conv2D)             (None, 3, 3, 512)    66048       activation_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_136 (BatchN (None, 3, 3, 512)    2048        conv2d_136[0][0]
# __________________________________________________________________________________________________
# batch_normalization_137 (BatchN (None, 3, 3, 512)    2048        conv2d_137[0][0]
# __________________________________________________________________________________________________
# batch_normalization_138 (BatchN (None, 3, 3, 512)    2048        conv2d_138[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 3, 3, 512)    0           batch_normalization_136[0][0]
#                                                                  batch_normalization_137[0][0]
#                                                                  batch_normalization_138[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 3, 3, 512)    0           add_28[0][0]
#                                                                  activation_98[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 3, 3, 512)    0           add_29[0][0]
# __________________________________________________________________________________________________
# conv2d_139 (Conv2D)             (None, 3, 3, 128)    65664       activation_105[0][0]
# __________________________________________________________________________________________________
# conv2d_140 (Conv2D)             (None, 3, 3, 128)    65664       activation_105[0][0]
# __________________________________________________________________________________________________
# conv2d_141 (Conv2D)             (None, 3, 3, 128)    65664       activation_105[0][0]
# __________________________________________________________________________________________________
# batch_normalization_139 (BatchN (None, 3, 3, 128)    512         conv2d_139[0][0]
# __________________________________________________________________________________________________
# batch_normalization_140 (BatchN (None, 3, 3, 128)    512         conv2d_140[0][0]
# __________________________________________________________________________________________________
# batch_normalization_141 (BatchN (None, 3, 3, 128)    512         conv2d_141[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 3, 3, 128)    0           batch_normalization_139[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, 3, 3, 128)    0           batch_normalization_140[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 3, 3, 128)    0           batch_normalization_141[0][0]
# __________________________________________________________________________________________________
# conv2d_142 (Conv2D)             (None, 3, 3, 128)    147584      activation_106[0][0]
# __________________________________________________________________________________________________
# conv2d_143 (Conv2D)             (None, 3, 3, 128)    147584      activation_107[0][0]
# __________________________________________________________________________________________________
# conv2d_144 (Conv2D)             (None, 3, 3, 128)    147584      activation_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_142 (BatchN (None, 3, 3, 128)    512         conv2d_142[0][0]
# __________________________________________________________________________________________________
# batch_normalization_143 (BatchN (None, 3, 3, 128)    512         conv2d_143[0][0]
# __________________________________________________________________________________________________
# batch_normalization_144 (BatchN (None, 3, 3, 128)    512         conv2d_144[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, 3, 3, 128)    0           batch_normalization_142[0][0]
# __________________________________________________________________________________________________
# activation_110 (Activation)     (None, 3, 3, 128)    0           batch_normalization_143[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, 3, 3, 128)    0           batch_normalization_144[0][0]
# __________________________________________________________________________________________________
# conv2d_145 (Conv2D)             (None, 3, 3, 512)    66048       activation_109[0][0]
# __________________________________________________________________________________________________
# conv2d_146 (Conv2D)             (None, 3, 3, 512)    66048       activation_110[0][0]
# __________________________________________________________________________________________________
# conv2d_147 (Conv2D)             (None, 3, 3, 512)    66048       activation_111[0][0]
# __________________________________________________________________________________________________
# batch_normalization_145 (BatchN (None, 3, 3, 512)    2048        conv2d_145[0][0]
# __________________________________________________________________________________________________
# batch_normalization_146 (BatchN (None, 3, 3, 512)    2048        conv2d_146[0][0]
# __________________________________________________________________________________________________
# batch_normalization_147 (BatchN (None, 3, 3, 512)    2048        conv2d_147[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 3, 3, 512)    0           batch_normalization_145[0][0]
#                                                                  batch_normalization_146[0][0]
#                                                                  batch_normalization_147[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 3, 3, 512)    0           add_30[0][0]
#                                                                  activation_105[0][0]
# __________________________________________________________________________________________________
# activation_112 (Activation)     (None, 3, 3, 512)    0           add_31[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 2, 2, 512)    0           activation_112[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2048)         0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 4)            8196        flatten[0][0]
# ==================================================================================================
# Total params: 4,162,980
# Trainable params: 4,126,948
# Non-trainable params: 36,032
# __________________________________________________________________________________________________

# %%
history = model.fit_generator(
           train_gen, steps_per_epoch=train_gen.samples // PARAMS['batch_size'], 
           epochs=PARAMS['epochs'],
         class_weight=class_weights,
           
           validation_data=test_gen)
           #callbacks=[checkpoint, lr_reduce])
# Out:
# WARNING:tensorflow:From <ipython-input-13-a8f9e88e93eb>:6: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 2587 steps, validate for 17 steps
# Epoch 1/35
# 2587/2587 [==============================] - 904s 349ms/step - loss: 1.0703 - categorical_accuracy: 0.6073 - val_loss: 1.0658 - val_categorical_accuracy: 0.6838
# Epoch 2/35
# 2587/2587 [==============================] - 577s 223ms/step - loss: 0.5328 - categorical_accuracy: 0.8136 - val_loss: 0.5326 - val_categorical_accuracy: 0.8088
# Epoch 3/35
# 2587/2587 [==============================] - 574s 222ms/step - loss: 0.4540 - categorical_accuracy: 0.8460 - val_loss: 0.7235 - val_categorical_accuracy: 0.7794
# Epoch 4/35
# 2587/2587 [==============================] - 577s 223ms/step - loss: 0.3824 - categorical_accuracy: 0.8704 - val_loss: 0.5790 - val_categorical_accuracy: 0.7629
# Epoch 5/35
# 2587/2587 [==============================] - 580s 224ms/step - loss: 0.3793 - categorical_accuracy: 0.8716 - val_loss: 0.2883 - val_categorical_accuracy: 0.9173
# Epoch 6/35
# 2587/2587 [==============================] - 577s 223ms/step - loss: 0.3130 - categorical_accuracy: 0.8958 - val_loss: 0.3167 - val_categorical_accuracy: 0.9136
# Epoch 7/35
# 2587/2587 [==============================] - 624s 241ms/step - loss: 0.2893 - categorical_accuracy: 0.9036 - val_loss: 0.1913 - val_categorical_accuracy: 0.9522
# Epoch 8/35
# 2587/2587 [==============================] - 720s 278ms/step - loss: 0.2712 - categorical_accuracy: 0.9095 - val_loss: 0.1992 - val_categorical_accuracy: 0.9540
# Epoch 9/35
# 2587/2587 [==============================] - 573s 221ms/step - loss: 0.2567 - categorical_accuracy: 0.9141 - val_loss: 0.3609 - val_categorical_accuracy: 0.8768
# Epoch 10/35
# 2587/2587 [==============================] - 572s 221ms/step - loss: 0.2417 - categorical_accuracy: 0.9195 - val_loss: 0.7747 - val_categorical_accuracy: 0.7941
# Epoch 11/35
# 2587/2587 [==============================] - 573s 221ms/step - loss: 0.2360 - categorical_accuracy: 0.9217 - val_loss: 0.5307 - val_categorical_accuracy: 0.8456
# Epoch 12/35
# 2587/2587 [==============================] - 571s 221ms/step - loss: 0.2254 - categorical_accuracy: 0.9248 - val_loss: 0.2973 - val_categorical_accuracy: 0.9026
# Epoch 13/35
# 2587/2587 [==============================] - 574s 222ms/step - loss: 0.2191 - categorical_accuracy: 0.9258 - val_loss: 0.2171 - val_categorical_accuracy: 0.9283
# Epoch 14/35
# 2587/2587 [==============================] - 576s 223ms/step - loss: 0.2244 - categorical_accuracy: 0.9269 - val_loss: 0.2378 - val_categorical_accuracy: 0.9320
# Epoch 15/35
# 2587/2587 [==============================] - 573s 221ms/step - loss: 0.2251 - categorical_accuracy: 0.9258 - val_loss: 0.6275 - val_categorical_accuracy: 0.7702
# Epoch 16/35
# 2587/2587 [==============================] - 572s 221ms/step - loss: 0.2438 - categorical_accuracy: 0.9194 - val_loss: 0.2570 - val_categorical_accuracy: 0.9210
# Epoch 17/35
# 2587/2587 [==============================] - 571s 221ms/step - loss: 0.1996 - categorical_accuracy: 0.9333 - val_loss: 0.1804 - val_categorical_accuracy: 0.9467
# Epoch 18/35
# 2587/2587 [==============================] - 570s 220ms/step - loss: 0.1916 - categorical_accuracy: 0.9355 - val_loss: 0.2102 - val_categorical_accuracy: 0.9357
# Epoch 19/35
# 2587/2587 [==============================] - 571s 221ms/step - loss: 0.1979 - categorical_accuracy: 0.9340 - val_loss: 0.1727 - val_categorical_accuracy: 0.9522
# Epoch 20/35
# 2587/2587 [==============================] - 573s 221ms/step - loss: 0.1845 - categorical_accuracy: 0.9382 - val_loss: 0.2793 - val_categorical_accuracy: 0.9062
# Epoch 21/35
# 2587/2587 [==============================] - 573s 222ms/step - loss: 0.2235 - categorical_accuracy: 0.9265 - val_loss: 0.1692 - val_categorical_accuracy: 0.9559
# Epoch 22/35
# 2587/2587 [==============================] - 574s 222ms/step - loss: 0.1840 - categorical_accuracy: 0.9377 - val_loss: 0.3268 - val_categorical_accuracy: 0.8971
# Epoch 23/35
# 2587/2587 [==============================] - 574s 222ms/step - loss: 0.1752 - categorical_accuracy: 0.9411 - val_loss: 0.3403 - val_categorical_accuracy: 0.8971
# Epoch 24/35
# 2587/2587 [==============================] - 574s 222ms/step - loss: 0.1715 - categorical_accuracy: 0.9424 - val_loss: 0.2299 - val_categorical_accuracy: 0.9393
# Epoch 25/35
# 2587/2587 [==============================] - 574s 222ms/step - loss: 0.1698 - categorical_accuracy: 0.9425 - val_loss: 0.6259 - val_categorical_accuracy: 0.8364
# Epoch 26/35
# 2587/2587 [==============================] - 574s 222ms/step - loss: 0.1742 - categorical_accuracy: 0.9416 - val_loss: 0.1401 - val_categorical_accuracy: 0.9596
# Epoch 27/35
# 2587/2587 [==============================] - 574s 222ms/step - loss: 0.1640 - categorical_accuracy: 0.9455 - val_loss: 0.2593 - val_categorical_accuracy: 0.9118
# Epoch 28/35
# 2587/2587 [==============================] - 574s 222ms/step - loss: 0.1615 - categorical_accuracy: 0.9459 - val_loss: 0.1408 - val_categorical_accuracy: 0.9577
# Epoch 29/35
# 2587/2587 [==============================] - 577s 223ms/step - loss: 0.1642 - categorical_accuracy: 0.9454 - val_loss: 0.1445 - val_categorical_accuracy: 0.9559
# Epoch 30/35
# 2587/2587 [==============================] - 582s 225ms/step - loss: 0.1565 - categorical_accuracy: 0.9478 - val_loss: 0.3056 - val_categorical_accuracy: 0.9044
# Epoch 31/35
# 2587/2587 [==============================] - 580s 224ms/step - loss: 0.1547 - categorical_accuracy: 0.9476 - val_loss: 0.2876 - val_categorical_accuracy: 0.9099
# Epoch 32/35
# 2587/2587 [==============================] - 580s 224ms/step - loss: 0.1509 - categorical_accuracy: 0.9492 - val_loss: 0.2797 - val_categorical_accuracy: 0.9081
# Epoch 33/35
# 2587/2587 [==============================] - 581s 225ms/step - loss: 0.1505 - categorical_accuracy: 0.9498 - val_loss: 0.1570 - val_categorical_accuracy: 0.9467
# Epoch 34/35
# 2587/2587 [==============================] - 575s 222ms/step - loss: 0.1466 - categorical_accuracy: 0.9509 - val_loss: 0.2528 - val_categorical_accuracy: 0.9301
# Epoch 35/35
# 2587/2587 [==============================] - 574s 222ms/step - loss: 0.1440 - categorical_accuracy: 0.9520 - val_loss: 0.2058 - val_categorical_accuracy: 0.9375

# %%
# Plot training & validation accuracy values
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
model.save("resNext3_OS")
# Out:
# WARNING:tensorflow:From c:\users\student-teoyongquan\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: resNext3_OS\assets

# %%
new_model = tf.keras.models.load_model('resnet_cw')

# Check its architecture
new_model.summary()

# %%
eval_test_datagen = ImageDataGenerator(
#  featurewise_center=True,
#  featurewise_std_normalization=True,
rescale=1./255)

# This is fed to the network in the specified batch sizes and image dimensions
eval_test_gen = eval_test_datagen.flow_from_directory(
directory = test_path, 
target_size = (160, 160), 
batch_size = 32,
class_mode = 'categorical', 
shuffle=False)
model.evaluate(eval_test_gen)
# Out:
# Found 16588 images belonging to 4 classes.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# 519/519 [==============================] - 116s 223ms/step - loss: 0.2479 - categorical_accuracy: 0.9196
# [0.24793069396151282, 0.9195804]

# %%
test_data = []
test_labels = []

for cond in ['/CNV/', '/DME/', '/DRUSEN/' ,'/NORMAL/']:
    for img in (os.listdir(test_path + cond)):
        img = plt.imread(test_path + cond + img)
        img = cv2.resize(img, (160, 160))
        img = np.dstack([img, img, img])

        img = img.astype('float32') / 255
        if cond=='/NORMAL/':
            label = 3
        elif cond=='/DME/':
            label = 1
        elif cond=='/DRUSEN/':
            label = 2
        elif cond=='/CNV/':
            label = 0
        test_data.append(img)
        test_labels.append(label)

test_data = np.array(test_data)
test_labels = np.array(test_labels)

#conf = confusion_matrix(test_labels, pred_ys)

# %%
Y = model.predict(test_data,batch_size = 32)
y_pred = np.argmax(Y,axis = 1)
print(test_labels)
print(y_pred)
num_errors = 0
print(len(y_pred))
for i in range(len(y_pred)):
    if y_pred[i] != test_labels[i]:
        num_errors += 1
        print("found another error, error count : ", num_errors)
# Out:
# [0 0 0 ... 3 3 3]
# [0 0 0 ... 3 3 3]
# 16588
# found another error, error count :  1
# found another error, error count :  2
# found another error, error count :  3
# found another error, error count :  4
# found another error, error count :  5
# found another error, error count :  6
# found another error, error count :  7
# found another error, error count :  8
# found another error, error count :  9
# found another error, error count :  10
# found another error, error count :  11
# found another error, error count :  12
# found another error, error count :  13
# found another error, error count :  14
# found another error, error count :  15
# found another error, error count :  16
# found another error, error count :  17
# found another error, error count :  18
# found another error, error count :  19
# found another error, error count :  20
# found another error, error count :  21
# found another error, error count :  22
# found another error, error count :  23
# found another error, error count :  24
# found another error, error count :  25
# found another error, error count :  26
# found another error, error count :  27
# found another error, error count :  28
# found another error, error count :  29
# found another error, error count :  30
# found another error, error count :  31
# found another error, error count :  32
# found another error, error count :  33
# found another error, error count :  34
# found another error, error count :  35
# found another error, error count :  36
# found another error, error count :  37
# found another error, error count :  38
# found another error, error count :  39
# found another error, error count :  40
# found another error, error count :  41
# found another error, error count :  42
# found another error, error count :  43
# found another error, error count :  44
# found another error, error count :  45
# found another error, error count :  46
# found another error, error count :  47
# found another error, error count :  48
# found another error, error count :  49
# found another error, error count :  50
# found another error, error count :  51
# found another error, error count :  52
# found another error, error count :  53
# found another error, error count :  54
# found another error, error count :  55
# found another error, error count :  56
# found another error, error count :  57
# found another error, error count :  58
# found another error, error count :  59
# found another error, error count :  60
# found another error, error count :  61
# found another error, error count :  62
# found another error, error count :  63
# found another error, error count :  64
# found another error, error count :  65
# found another error, error count :  66
# found another error, error count :  67
# found another error, error count :  68
# found another error, error count :  69
# found another error, error count :  70
# found another error, error count :  71
# found another error, error count :  72
# found another error, error count :  73
# found another error, error count :  74
# found another error, error count :  75
# found another error, error count :  76
# found another error, error count :  77
# found another error, error count :  78
# found another error, error count :  79
# found another error, error count :  80
# found another error, error count :  81
# found another error, error count :  82
# found another error, error count :  83
# found another error, error count :  84
# found another error, error count :  85
# found another error, error count :  86
# found another error, error count :  87
# found another error, error count :  88
# found another error, error count :  89
# found another error, error count :  90
# found another error, error count :  91
# found another error, error count :  92
# found another error, error count :  93
# found another error, error count :  94
# found another error, error count :  95
# found another error, error count :  96
# found another error, error count :  97
# found another error, error count :  98
# found another error, error count :  99
# found another error, error count :  100
# found another error, error count :  101
# found another error, error count :  102
# found another error, error count :  103
# found another error, error count :  104
# found another error, error count :  105
# found another error, error count :  106
# found another error, error count :  107
# found another error, error count :  108
# found another error, error count :  109
# found another error, error count :  110
# found another error, error count :  111
# found another error, error count :  112
# found another error, error count :  113
# found another error, error count :  114
# found another error, error count :  115
# found another error, error count :  116
# found another error, error count :  117
# found another error, error count :  118
# found another error, error count :  119
# found another error, error count :  120
# found another error, error count :  121
# found another error, error count :  122
# found another error, error count :  123
# found another error, error count :  124
# found another error, error count :  125
# found another error, error count :  126
# found another error, error count :  127
# found another error, error count :  128
# found another error, error count :  129
# found another error, error count :  130
# found another error, error count :  131
# found another error, error count :  132
# found another error, error count :  133
# found another error, error count :  134
# found another error, error count :  135
# found another error, error count :  136
# found another error, error count :  137
# found another error, error count :  138
# found another error, error count :  139
# found another error, error count :  140
# found another error, error count :  141
# found another error, error count :  142
# found another error, error count :  143
# found another error, error count :  144
# found another error, error count :  145
# found another error, error count :  146
# found another error, error count :  147
# found another error, error count :  148
# found another error, error count :  149
# found another error, error count :  150
# found another error, error count :  151
# found another error, error count :  152
# found another error, error count :  153
# found another error, error count :  154
# found another error, error count :  155
# found another error, error count :  156
# found another error, error count :  157
# found another error, error count :  158
# found another error, error count :  159
# found another error, error count :  160
# found another error, error count :  161
# found another error, error count :  162
# found another error, error count :  163
# found another error, error count :  164
# found another error, error count :  165
# found another error, error count :  166
# found another error, error count :  167
# found another error, error count :  168
# found another error, error count :  169
# found another error, error count :  170
# found another error, error count :  171
# found another error, error count :  172
# found another error, error count :  173
# found another error, error count :  174
# found another error, error count :  175
# found another error, error count :  176
# found another error, error count :  177
# found another error, error count :  178
# found another error, error count :  179
# found another error, error count :  180
# found another error, error count :  181
# found another error, error count :  182
# found another error, error count :  183
# found another error, error count :  184
# found another error, error count :  185
# found another error, error count :  186
# found another error, error count :  187
# found another error, error count :  188
# found another error, error count :  189
# found another error, error count :  190
# found another error, error count :  191
# found another error, error count :  192
# found another error, error count :  193
# found another error, error count :  194
# found another error, error count :  195
# found another error, error count :  196
# found another error, error count :  197
# found another error, error count :  198
# found another error, error count :  199
# found another error, error count :  200
# found another error, error count :  201
# found another error, error count :  202
# found another error, error count :  203
# found another error, error count :  204
# found another error, error count :  205
# found another error, error count :  206
# found another error, error count :  207
# found another error, error count :  208
# found another error, error count :  209
# found another error, error count :  210
# found another error, error count :  211
# found another error, error count :  212
# found another error, error count :  213
# found another error, error count :  214
# found another error, error count :  215
# found another error, error count :  216
# found another error, error count :  217
# found another error, error count :  218
# found another error, error count :  219
# found another error, error count :  220
# found another error, error count :  221
# found another error, error count :  222
# found another error, error count :  223
# found another error, error count :  224
# found another error, error count :  225
# found another error, error count :  226
# found another error, error count :  227
# found another error, error count :  228
# found another error, error count :  229
# found another error, error count :  230
# found another error, error count :  231
# found another error, error count :  232
# found another error, error count :  233
# found another error, error count :  234
# found another error, error count :  235
# found another error, error count :  236
# found another error, error count :  237
# found another error, error count :  238
# found another error, error count :  239
# found another error, error count :  240
# found another error, error count :  241
# found another error, error count :  242
# found another error, error count :  243
# found another error, error count :  244
# found another error, error count :  245
# found another error, error count :  246
# found another error, error count :  247
# found another error, error count :  248
# found another error, error count :  249
# found another error, error count :  250
# found another error, error count :  251
# found another error, error count :  252
# found another error, error count :  253
# found another error, error count :  254
# found another error, error count :  255
# found another error, error count :  256
# found another error, error count :  257
# found another error, error count :  258
# found another error, error count :  259
# found another error, error count :  260
# found another error, error count :  261
# found another error, error count :  262
# found another error, error count :  263
# found another error, error count :  264
# found another error, error count :  265
# found another error, error count :  266
# found another error, error count :  267
# found another error, error count :  268
# found another error, error count :  269
# found another error, error count :  270
# found another error, error count :  271
# found another error, error count :  272
# found another error, error count :  273
# found another error, error count :  274
# found another error, error count :  275
# found another error, error count :  276
# found another error, error count :  277
# found another error, error count :  278
# found another error, error count :  279
# found another error, error count :  280
# found another error, error count :  281
# found another error, error count :  282
# found another error, error count :  283
# found another error, error count :  284
# found another error, error count :  285
# found another error, error count :  286
# found another error, error count :  287
# found another error, error count :  288
# found another error, error count :  289
# found another error, error count :  290
# found another error, error count :  291
# found another error, error count :  292
# found another error, error count :  293
# found another error, error count :  294
# found another error, error count :  295
# found another error, error count :  296
# found another error, error count :  297
# found another error, error count :  298
# found another error, error count :  299
# found another error, error count :  300
# found another error, error count :  301
# found another error, error count :  302
# found another error, error count :  303
# found another error, error count :  304
# found another error, error count :  305
# found another error, error count :  306
# found another error, error count :  307
# found another error, error count :  308
# found another error, error count :  309
# found another error, error count :  310
# found another error, error count :  311
# found another error, error count :  312
# found another error, error count :  313
# found another error, error count :  314
# found another error, error count :  315
# found another error, error count :  316
# found another error, error count :  317
# found another error, error count :  318
# found another error, error count :  319
# found another error, error count :  320
# found another error, error count :  321
# found another error, error count :  322
# found another error, error count :  323
# found another error, error count :  324
# found another error, error count :  325
# found another error, error count :  326
# found another error, error count :  327
# found another error, error count :  328
# found another error, error count :  329
# found another error, error count :  330
# found another error, error count :  331
# found another error, error count :  332
# found another error, error count :  333
# found another error, error count :  334
# found another error, error count :  335
# found another error, error count :  336
# found another error, error count :  337
# found another error, error count :  338
# found another error, error count :  339
# found another error, error count :  340
# found another error, error count :  341
# found another error, error count :  342
# found another error, error count :  343
# found another error, error count :  344
# found another error, error count :  345
# found another error, error count :  346
# found another error, error count :  347
# found another error, error count :  348
# found another error, error count :  349
# found another error, error count :  350
# found another error, error count :  351
# found another error, error count :  352
# found another error, error count :  353
# found another error, error count :  354
# found another error, error count :  355
# found another error, error count :  356
# found another error, error count :  357
# found another error, error count :  358
# found another error, error count :  359
# found another error, error count :  360
# found another error, error count :  361
# found another error, error count :  362
# found another error, error count :  363
# found another error, error count :  364
# found another error, error count :  365
# found another error, error count :  366
# found another error, error count :  367
# found another error, error count :  368
# found another error, error count :  369
# found another error, error count :  370
# found another error, error count :  371
# found another error, error count :  372
# found another error, error count :  373
# found another error, error count :  374
# found another error, error count :  375
# found another error, error count :  376
# found another error, error count :  377
# found another error, error count :  378
# found another error, error count :  379
# found another error, error count :  380
# found another error, error count :  381
# found another error, error count :  382
# found another error, error count :  383
# found another error, error count :  384
# found another error, error count :  385
# found another error, error count :  386
# found another error, error count :  387
# found another error, error count :  388
# found another error, error count :  389
# found another error, error count :  390
# found another error, error count :  391
# found another error, error count :  392
# found another error, error count :  393
# found another error, error count :  394
# found another error, error count :  395
# found another error, error count :  396
# found another error, error count :  397
# found another error, error count :  398
# found another error, error count :  399
# found another error, error count :  400
# found another error, error count :  401
# found another error, error count :  402
# found another error, error count :  403
# found another error, error count :  404
# found another error, error count :  405
# found another error, error count :  406
# found another error, error count :  407
# found another error, error count :  408
# found another error, error count :  409
# found another error, error count :  410
# found another error, error count :  411
# found another error, error count :  412
# found another error, error count :  413
# found another error, error count :  414
# found another error, error count :  415
# found another error, error count :  416
# found another error, error count :  417
# found another error, error count :  418
# found another error, error count :  419
# found another error, error count :  420
# found another error, error count :  421
# found another error, error count :  422
# found another error, error count :  423
# found another error, error count :  424
# found another error, error count :  425
# found another error, error count :  426
# found another error, error count :  427
# found another error, error count :  428
# found another error, error count :  429
# found another error, error count :  430
# found another error, error count :  431
# found another error, error count :  432
# found another error, error count :  433
# found another error, error count :  434
# found another error, error count :  435
# found another error, error count :  436
# found another error, error count :  437
# found another error, error count :  438
# found another error, error count :  439
# found another error, error count :  440
# found another error, error count :  441
# found another error, error count :  442
# found another error, error count :  443
# found another error, error count :  444
# found another error, error count :  445
# found another error, error count :  446
# found another error, error count :  447
# found another error, error count :  448
# found another error, error count :  449
# found another error, error count :  450
# found another error, error count :  451
# found another error, error count :  452
# found another error, error count :  453
# found another error, error count :  454
# found another error, error count :  455
# found another error, error count :  456
# found another error, error count :  457
# found another error, error count :  458
# found another error, error count :  459
# found another error, error count :  460
# found another error, error count :  461
# found another error, error count :  462
# found another error, error count :  463
# found another error, error count :  464
# found another error, error count :  465
# found another error, error count :  466
# found another error, error count :  467
# found another error, error count :  468
# found another error, error count :  469
# found another error, error count :  470
# found another error, error count :  471
# found another error, error count :  472
# found another error, error count :  473
# found another error, error count :  474
# found another error, error count :  475
# found another error, error count :  476
# found another error, error count :  477
# found another error, error count :  478
# found another error, error count :  479
# found another error, error count :  480
# found another error, error count :  481
# found another error, error count :  482
# found another error, error count :  483
# found another error, error count :  484
# found another error, error count :  485
# found another error, error count :  486
# found another error, error count :  487
# found another error, error count :  488
# found another error, error count :  489
# found another error, error count :  490
# found another error, error count :  491
# found another error, error count :  492
# found another error, error count :  493
# found another error, error count :  494
# found another error, error count :  495
# found another error, error count :  496
# found another error, error count :  497
# found another error, error count :  498
# found another error, error count :  499
# found another error, error count :  500
# found another error, error count :  501
# found another error, error count :  502
# found another error, error count :  503
# found another error, error count :  504
# found another error, error count :  505
# found another error, error count :  506
# found another error, error count :  507
# found another error, error count :  508
# found another error, error count :  509
# found another error, error count :  510
# found another error, error count :  511
# found another error, error count :  512
# found another error, error count :  513
# found another error, error count :  514
# found another error, error count :  515
# found another error, error count :  516
# found another error, error count :  517
# found another error, error count :  518
# found another error, error count :  519
# found another error, error count :  520
# found another error, error count :  521
# found another error, error count :  522
# found another error, error count :  523
# found another error, error count :  524
# found another error, error count :  525
# found another error, error count :  526
# found another error, error count :  527
# found another error, error count :  528
# found another error, error count :  529
# found another error, error count :  530
# found another error, error count :  531
# found another error, error count :  532
# found another error, error count :  533
# found another error, error count :  534
# found another error, error count :  535
# found another error, error count :  536
# found another error, error count :  537
# found another error, error count :  538
# found another error, error count :  539
# found another error, error count :  540
# found another error, error count :  541
# found another error, error count :  542
# found another error, error count :  543
# found another error, error count :  544
# found another error, error count :  545
# found another error, error count :  546
# found another error, error count :  547
# found another error, error count :  548
# found another error, error count :  549
# found another error, error count :  550
# found another error, error count :  551
# found another error, error count :  552
# found another error, error count :  553
# found another error, error count :  554
# found another error, error count :  555
# found another error, error count :  556
# found another error, error count :  557
# found another error, error count :  558
# found another error, error count :  559
# found another error, error count :  560
# found another error, error count :  561
# found another error, error count :  562
# found another error, error count :  563
# found another error, error count :  564
# found another error, error count :  565
# found another error, error count :  566
# found another error, error count :  567
# found another error, error count :  568
# found another error, error count :  569
# found another error, error count :  570
# found another error, error count :  571
# found another error, error count :  572
# found another error, error count :  573
# found another error, error count :  574
# found another error, error count :  575
# found another error, error count :  576
# found another error, error count :  577
# found another error, error count :  578
# found another error, error count :  579
# found another error, error count :  580
# found another error, error count :  581
# found another error, error count :  582
# found another error, error count :  583
# found another error, error count :  584
# found another error, error count :  585
# found another error, error count :  586
# found another error, error count :  587
# found another error, error count :  588
# found another error, error count :  589
# found another error, error count :  590
# found another error, error count :  591
# found another error, error count :  592
# found another error, error count :  593
# found another error, error count :  594
# found another error, error count :  595
# found another error, error count :  596
# found another error, error count :  597
# found another error, error count :  598
# found another error, error count :  599
# found another error, error count :  600
# found another error, error count :  601
# found another error, error count :  602
# found another error, error count :  603
# found another error, error count :  604
# found another error, error count :  605
# found another error, error count :  606
# found another error, error count :  607
# found another error, error count :  608
# found another error, error count :  609
# found another error, error count :  610
# found another error, error count :  611
# found another error, error count :  612
# found another error, error count :  613
# found another error, error count :  614
# found another error, error count :  615
# found another error, error count :  616
# found another error, error count :  617
# found another error, error count :  618
# found another error, error count :  619
# found another error, error count :  620
# found another error, error count :  621
# found another error, error count :  622
# found another error, error count :  623
# found another error, error count :  624
# found another error, error count :  625
# found another error, error count :  626
# found another error, error count :  627
# found another error, error count :  628
# found another error, error count :  629
# found another error, error count :  630
# found another error, error count :  631
# found another error, error count :  632
# found another error, error count :  633
# found another error, error count :  634
# found another error, error count :  635
# found another error, error count :  636
# found another error, error count :  637
# found another error, error count :  638
# found another error, error count :  639
# found another error, error count :  640
# found another error, error count :  641
# found another error, error count :  642
# found another error, error count :  643
# found another error, error count :  644
# found another error, error count :  645
# found another error, error count :  646
# found another error, error count :  647
# found another error, error count :  648
# found another error, error count :  649
# found another error, error count :  650
# found another error, error count :  651
# found another error, error count :  652
# found another error, error count :  653
# found another error, error count :  654
# found another error, error count :  655
# found another error, error count :  656
# found another error, error count :  657
# found another error, error count :  658
# found another error, error count :  659
# found another error, error count :  660
# found another error, error count :  661
# found another error, error count :  662
# found another error, error count :  663
# found another error, error count :  664
# found another error, error count :  665
# found another error, error count :  666
# found another error, error count :  667
# found another error, error count :  668
# found another error, error count :  669
# found another error, error count :  670
# found another error, error count :  671
# found another error, error count :  672
# found another error, error count :  673
# found another error, error count :  674
# found another error, error count :  675
# found another error, error count :  676
# found another error, error count :  677
# found another error, error count :  678
# found another error, error count :  679
# found another error, error count :  680
# found another error, error count :  681
# found another error, error count :  682
# found another error, error count :  683
# found another error, error count :  684
# found another error, error count :  685
# found another error, error count :  686
# found another error, error count :  687
# found another error, error count :  688
# found another error, error count :  689
# found another error, error count :  690
# found another error, error count :  691
# found another error, error count :  692
# found another error, error count :  693
# found another error, error count :  694
# found another error, error count :  695
# found another error, error count :  696
# found another error, error count :  697
# found another error, error count :  698
# found another error, error count :  699
# found another error, error count :  700
# found another error, error count :  701
# found another error, error count :  702
# found another error, error count :  703
# found another error, error count :  704
# found another error, error count :  705
# found another error, error count :  706
# found another error, error count :  707
# found another error, error count :  708
# found another error, error count :  709
# found another error, error count :  710
# found another error, error count :  711
# found another error, error count :  712
# found another error, error count :  713
# found another error, error count :  714
# found another error, error count :  715
# found another error, error count :  716
# found another error, error count :  717
# found another error, error count :  718
# found another error, error count :  719
# found another error, error count :  720
# found another error, error count :  721
# found another error, error count :  722
# found another error, error count :  723
# found another error, error count :  724
# found another error, error count :  725
# found another error, error count :  726
# found another error, error count :  727
# found another error, error count :  728
# found another error, error count :  729
# found another error, error count :  730
# found another error, error count :  731
# found another error, error count :  732
# found another error, error count :  733
# found another error, error count :  734
# found another error, error count :  735
# found another error, error count :  736
# found another error, error count :  737
# found another error, error count :  738
# found another error, error count :  739
# found another error, error count :  740
# found another error, error count :  741
# found another error, error count :  742
# found another error, error count :  743
# found another error, error count :  744
# found another error, error count :  745
# found another error, error count :  746
# found another error, error count :  747
# found another error, error count :  748
# found another error, error count :  749
# found another error, error count :  750
# found another error, error count :  751
# found another error, error count :  752
# found another error, error count :  753
# found another error, error count :  754
# found another error, error count :  755
# found another error, error count :  756
# found another error, error count :  757
# found another error, error count :  758
# found another error, error count :  759
# found another error, error count :  760
# found another error, error count :  761
# found another error, error count :  762
# found another error, error count :  763
# found another error, error count :  764
# found another error, error count :  765
# found another error, error count :  766
# found another error, error count :  767
# found another error, error count :  768
# found another error, error count :  769
# found another error, error count :  770
# found another error, error count :  771
# found another error, error count :  772
# found another error, error count :  773
# found another error, error count :  774
# found another error, error count :  775
# found another error, error count :  776
# found another error, error count :  777
# found another error, error count :  778
# found another error, error count :  779
# found another error, error count :  780
# found another error, error count :  781
# found another error, error count :  782
# found another error, error count :  783
# found another error, error count :  784
# found another error, error count :  785
# found another error, error count :  786
# found another error, error count :  787
# found another error, error count :  788
# found another error, error count :  789
# found another error, error count :  790
# found another error, error count :  791
# found another error, error count :  792
# found another error, error count :  793
# found another error, error count :  794
# found another error, error count :  795
# found another error, error count :  796
# found another error, error count :  797
# found another error, error count :  798
# found another error, error count :  799
# found another error, error count :  800
# found another error, error count :  801
# found another error, error count :  802
# found another error, error count :  803
# found another error, error count :  804
# found another error, error count :  805
# found another error, error count :  806
# found another error, error count :  807
# found another error, error count :  808
# found another error, error count :  809
# found another error, error count :  810
# found another error, error count :  811
# found another error, error count :  812
# found another error, error count :  813
# found another error, error count :  814
# found another error, error count :  815
# found another error, error count :  816
# found another error, error count :  817
# found another error, error count :  818
# found another error, error count :  819
# found another error, error count :  820
# found another error, error count :  821
# found another error, error count :  822
# found another error, error count :  823
# found another error, error count :  824
# found another error, error count :  825
# found another error, error count :  826
# found another error, error count :  827
# found another error, error count :  828
# found another error, error count :  829
# found another error, error count :  830
# found another error, error count :  831
# found another error, error count :  832
# found another error, error count :  833
# found another error, error count :  834
# found another error, error count :  835
# found another error, error count :  836
# found another error, error count :  837
# found another error, error count :  838
# found another error, error count :  839
# found another error, error count :  840
# found another error, error count :  841
# found another error, error count :  842
# found another error, error count :  843
# found another error, error count :  844
# found another error, error count :  845
# found another error, error count :  846
# found another error, error count :  847
# found another error, error count :  848
# found another error, error count :  849
# found another error, error count :  850
# found another error, error count :  851
# found another error, error count :  852
# found another error, error count :  853
# found another error, error count :  854
# found another error, error count :  855
# found another error, error count :  856
# found another error, error count :  857
# found another error, error count :  858
# found another error, error count :  859
# found another error, error count :  860
# found another error, error count :  861
# found another error, error count :  862
# found another error, error count :  863
# found another error, error count :  864
# found another error, error count :  865
# found another error, error count :  866
# found another error, error count :  867
# found another error, error count :  868
# found another error, error count :  869
# found another error, error count :  870
# found another error, error count :  871
# found another error, error count :  872
# found another error, error count :  873
# found another error, error count :  874
# found another error, error count :  875
# found another error, error count :  876
# found another error, error count :  877
# found another error, error count :  878
# found another error, error count :  879
# found another error, error count :  880
# found another error, error count :  881
# found another error, error count :  882
# found another error, error count :  883
# found another error, error count :  884
# found another error, error count :  885
# found another error, error count :  886
# found another error, error count :  887
# found another error, error count :  888
# found another error, error count :  889
# found another error, error count :  890
# found another error, error count :  891
# found another error, error count :  892
# found another error, error count :  893
# found another error, error count :  894
# found another error, error count :  895
# found another error, error count :  896
# found another error, error count :  897
# found another error, error count :  898
# found another error, error count :  899
# found another error, error count :  900
# found another error, error count :  901
# found another error, error count :  902
# found another error, error count :  903
# found another error, error count :  904
# found another error, error count :  905
# found another error, error count :  906
# found another error, error count :  907
# found another error, error count :  908
# found another error, error count :  909
# found another error, error count :  910
# found another error, error count :  911
# found another error, error count :  912
# found another error, error count :  913
# found another error, error count :  914
# found another error, error count :  915
# found another error, error count :  916
# found another error, error count :  917
# found another error, error count :  918
# found another error, error count :  919
# found another error, error count :  920
# found another error, error count :  921
# found another error, error count :  922
# found another error, error count :  923
# found another error, error count :  924
# found another error, error count :  925
# found another error, error count :  926
# found another error, error count :  927
# found another error, error count :  928
# found another error, error count :  929
# found another error, error count :  930
# found another error, error count :  931
# found another error, error count :  932
# found another error, error count :  933
# found another error, error count :  934
# found another error, error count :  935
# found another error, error count :  936
# found another error, error count :  937
# found another error, error count :  938
# found another error, error count :  939
# found another error, error count :  940
# found another error, error count :  941
# found another error, error count :  942
# found another error, error count :  943
# found another error, error count :  944
# found another error, error count :  945
# found another error, error count :  946
# found another error, error count :  947
# found another error, error count :  948
# found another error, error count :  949
# found another error, error count :  950
# found another error, error count :  951
# found another error, error count :  952
# found another error, error count :  953
# found another error, error count :  954
# found another error, error count :  955
# found another error, error count :  956
# found another error, error count :  957
# found another error, error count :  958
# found another error, error count :  959
# found another error, error count :  960
# found another error, error count :  961
# found another error, error count :  962
# found another error, error count :  963
# found another error, error count :  964
# found another error, error count :  965
# found another error, error count :  966
# found another error, error count :  967
# found another error, error count :  968
# found another error, error count :  969
# found another error, error count :  970
# found another error, error count :  971
# found another error, error count :  972
# found another error, error count :  973
# found another error, error count :  974
# found another error, error count :  975
# found another error, error count :  976
# found another error, error count :  977
# found another error, error count :  978
# found another error, error count :  979
# found another error, error count :  980
# found another error, error count :  981
# found another error, error count :  982
# found another error, error count :  983
# found another error, error count :  984
# found another error, error count :  985
# found another error, error count :  986
# found another error, error count :  987
# found another error, error count :  988
# found another error, error count :  989
# found another error, error count :  990
# found another error, error count :  991
# found another error, error count :  992
# found another error, error count :  993
# found another error, error count :  994
# found another error, error count :  995
# found another error, error count :  996
# found another error, error count :  997
# found another error, error count :  998
# found another error, error count :  999
# found another error, error count :  1000
# found another error, error count :  1001
# found another error, error count :  1002
# found another error, error count :  1003
# found another error, error count :  1004
# found another error, error count :  1005
# found another error, error count :  1006
# found another error, error count :  1007
# found another error, error count :  1008
# found another error, error count :  1009
# found another error, error count :  1010
# found another error, error count :  1011
# found another error, error count :  1012
# found another error, error count :  1013
# found another error, error count :  1014
# found another error, error count :  1015
# found another error, error count :  1016
# found another error, error count :  1017
# found another error, error count :  1018
# found another error, error count :  1019
# found another error, error count :  1020
# found another error, error count :  1021
# found another error, error count :  1022
# found another error, error count :  1023
# found another error, error count :  1024
# found another error, error count :  1025
# found another error, error count :  1026
# found another error, error count :  1027
# found another error, error count :  1028
# found another error, error count :  1029
# found another error, error count :  1030
# found another error, error count :  1031
# found another error, error count :  1032
# found another error, error count :  1033
# found another error, error count :  1034
# found another error, error count :  1035
# found another error, error count :  1036
# found another error, error count :  1037
# found another error, error count :  1038
# found another error, error count :  1039
# found another error, error count :  1040
# found another error, error count :  1041
# found another error, error count :  1042
# found another error, error count :  1043
# found another error, error count :  1044
# found another error, error count :  1045
# found another error, error count :  1046
# found another error, error count :  1047
# found another error, error count :  1048
# found another error, error count :  1049
# found another error, error count :  1050
# found another error, error count :  1051
# found another error, error count :  1052
# found another error, error count :  1053
# found another error, error count :  1054
# found another error, error count :  1055
# found another error, error count :  1056
# found another error, error count :  1057
# found another error, error count :  1058
# found another error, error count :  1059
# found another error, error count :  1060
# found another error, error count :  1061
# found another error, error count :  1062
# found another error, error count :  1063
# found another error, error count :  1064
# found another error, error count :  1065
# found another error, error count :  1066
# found another error, error count :  1067
# found another error, error count :  1068
# found another error, error count :  1069
# found another error, error count :  1070
# found another error, error count :  1071
# found another error, error count :  1072
# found another error, error count :  1073
# found another error, error count :  1074
# found another error, error count :  1075
# found another error, error count :  1076
# found another error, error count :  1077
# found another error, error count :  1078
# found another error, error count :  1079
# found another error, error count :  1080
# found another error, error count :  1081
# found another error, error count :  1082
# found another error, error count :  1083
# found another error, error count :  1084
# found another error, error count :  1085
# found another error, error count :  1086
# found another error, error count :  1087
# found another error, error count :  1088
# found another error, error count :  1089
# found another error, error count :  1090
# found another error, error count :  1091
# found another error, error count :  1092
# found another error, error count :  1093
# found another error, error count :  1094
# found another error, error count :  1095
# found another error, error count :  1096
# found another error, error count :  1097
# found another error, error count :  1098
# found another error, error count :  1099
# found another error, error count :  1100
# found another error, error count :  1101
# found another error, error count :  1102
# found another error, error count :  1103
# found another error, error count :  1104
# found another error, error count :  1105
# found another error, error count :  1106
# found another error, error count :  1107
# found another error, error count :  1108
# found another error, error count :  1109
# found another error, error count :  1110
# found another error, error count :  1111
# found another error, error count :  1112
# found another error, error count :  1113
# found another error, error count :  1114
# found another error, error count :  1115
# found another error, error count :  1116
# found another error, error count :  1117
# found another error, error count :  1118
# found another error, error count :  1119
# found another error, error count :  1120
# found another error, error count :  1121
# found another error, error count :  1122
# found another error, error count :  1123
# found another error, error count :  1124
# found another error, error count :  1125
# found another error, error count :  1126
# found another error, error count :  1127
# found another error, error count :  1128
# found another error, error count :  1129
# found another error, error count :  1130
# found another error, error count :  1131
# found another error, error count :  1132
# found another error, error count :  1133
# found another error, error count :  1134
# found another error, error count :  1135
# found another error, error count :  1136
# found another error, error count :  1137
# found another error, error count :  1138
# found another error, error count :  1139
# found another error, error count :  1140
# found another error, error count :  1141
# found another error, error count :  1142
# found another error, error count :  1143
# found another error, error count :  1144
# found another error, error count :  1145
# found another error, error count :  1146
# found another error, error count :  1147
# found another error, error count :  1148
# found another error, error count :  1149
# found another error, error count :  1150
# found another error, error count :  1151
# found another error, error count :  1152
# found another error, error count :  1153
# found another error, error count :  1154
# found another error, error count :  1155
# found another error, error count :  1156
# found another error, error count :  1157
# found another error, error count :  1158
# found another error, error count :  1159
# found another error, error count :  1160
# found another error, error count :  1161
# found another error, error count :  1162
# found another error, error count :  1163
# found another error, error count :  1164
# found another error, error count :  1165
# found another error, error count :  1166
# found another error, error count :  1167
# found another error, error count :  1168
# found another error, error count :  1169
# found another error, error count :  1170
# found another error, error count :  1171
# found another error, error count :  1172
# found another error, error count :  1173
# found another error, error count :  1174
# found another error, error count :  1175
# found another error, error count :  1176
# found another error, error count :  1177
# found another error, error count :  1178
# found another error, error count :  1179
# found another error, error count :  1180
# found another error, error count :  1181
# found another error, error count :  1182
# found another error, error count :  1183
# found another error, error count :  1184
# found another error, error count :  1185
# found another error, error count :  1186
# found another error, error count :  1187
# found another error, error count :  1188
# found another error, error count :  1189
# found another error, error count :  1190
# found another error, error count :  1191
# found another error, error count :  1192
# found another error, error count :  1193
# found another error, error count :  1194
# found another error, error count :  1195
# found another error, error count :  1196
# found another error, error count :  1197
# found another error, error count :  1198
# found another error, error count :  1199
# found another error, error count :  1200
# found another error, error count :  1201
# found another error, error count :  1202
# found another error, error count :  1203
# found another error, error count :  1204
# found another error, error count :  1205
# found another error, error count :  1206
# found another error, error count :  1207
# found another error, error count :  1208
# found another error, error count :  1209
# found another error, error count :  1210
# found another error, error count :  1211
# found another error, error count :  1212
# found another error, error count :  1213
# found another error, error count :  1214
# found another error, error count :  1215
# found another error, error count :  1216
# found another error, error count :  1217
# found another error, error count :  1218
# found another error, error count :  1219
# found another error, error count :  1220
# found another error, error count :  1221
# found another error, error count :  1222
# found another error, error count :  1223
# found another error, error count :  1224
# found another error, error count :  1225
# found another error, error count :  1226
# found another error, error count :  1227
# found another error, error count :  1228
# found another error, error count :  1229
# found another error, error count :  1230
# found another error, error count :  1231
# found another error, error count :  1232
# found another error, error count :  1233
# found another error, error count :  1234
# found another error, error count :  1235
# found another error, error count :  1236
# found another error, error count :  1237
# found another error, error count :  1238
# found another error, error count :  1239
# found another error, error count :  1240
# found another error, error count :  1241
# found another error, error count :  1242
# found another error, error count :  1243
# found another error, error count :  1244
# found another error, error count :  1245
# found another error, error count :  1246
# found another error, error count :  1247
# found another error, error count :  1248
# found another error, error count :  1249
# found another error, error count :  1250
# found another error, error count :  1251
# found another error, error count :  1252
# found another error, error count :  1253
# found another error, error count :  1254
# found another error, error count :  1255
# found another error, error count :  1256
# found another error, error count :  1257
# found another error, error count :  1258
# found another error, error count :  1259
# found another error, error count :  1260
# found another error, error count :  1261
# found another error, error count :  1262
# found another error, error count :  1263
# found another error, error count :  1264
# found another error, error count :  1265
# found another error, error count :  1266
# found another error, error count :  1267
# found another error, error count :  1268
# found another error, error count :  1269
# found another error, error count :  1270
# found another error, error count :  1271
# found another error, error count :  1272
# found another error, error count :  1273
# found another error, error count :  1274
# found another error, error count :  1275
# found another error, error count :  1276
# found another error, error count :  1277
# found another error, error count :  1278
# found another error, error count :  1279
# found another error, error count :  1280
# found another error, error count :  1281
# found another error, error count :  1282
# found another error, error count :  1283
# found another error, error count :  1284
# found another error, error count :  1285
# found another error, error count :  1286
# found another error, error count :  1287
# found another error, error count :  1288
# found another error, error count :  1289
# found another error, error count :  1290
# found another error, error count :  1291
# found another error, error count :  1292
# found another error, error count :  1293
# found another error, error count :  1294
# found another error, error count :  1295
# found another error, error count :  1296
# found another error, error count :  1297
# found another error, error count :  1298
# found another error, error count :  1299
# found another error, error count :  1300
# found another error, error count :  1301
# found another error, error count :  1302
# found another error, error count :  1303
# found another error, error count :  1304
# found another error, error count :  1305
# found another error, error count :  1306
# found another error, error count :  1307
# found another error, error count :  1308
# found another error, error count :  1309
# found another error, error count :  1310
# found another error, error count :  1311
# found another error, error count :  1312
# found another error, error count :  1313
# found another error, error count :  1314
# found another error, error count :  1315
# found another error, error count :  1316
# found another error, error count :  1317
# found another error, error count :  1318
# found another error, error count :  1319
# found another error, error count :  1320
# found another error, error count :  1321
# found another error, error count :  1322
# found another error, error count :  1323
# found another error, error count :  1324
# found another error, error count :  1325
# found another error, error count :  1326
# found another error, error count :  1327
# found another error, error count :  1328
# found another error, error count :  1329
# found another error, error count :  1330
# found another error, error count :  1331
# found another error, error count :  1332
# found another error, error count :  1333
# found another error, error count :  1334
# found another error, error count :  1335
# found another error, error count :  1336
# found another error, error count :  1337
# found another error, error count :  1338
# found another error, error count :  1339
# found another error, error count :  1340
# found another error, error count :  1341
# found another error, error count :  1342
# found another error, error count :  1343
# found another error, error count :  1344
# found another error, error count :  1345
# found another error, error count :  1346
# found another error, error count :  1347
# found another error, error count :  1348
# found another error, error count :  1349
# found another error, error count :  1350
# found another error, error count :  1351
# found another error, error count :  1352
# found another error, error count :  1353
# found another error, error count :  1354
# found another error, error count :  1355
# found another error, error count :  1356
# found another error, error count :  1357
# found another error, error count :  1358
# found another error, error count :  1359
# found another error, error count :  1360
# found another error, error count :  1361
# found another error, error count :  1362
# found another error, error count :  1363
# found another error, error count :  1364
# found another error, error count :  1365
# found another error, error count :  1366
# found another error, error count :  1367
# found another error, error count :  1368
# found another error, error count :  1369
# found another error, error count :  1370
# found another error, error count :  1371
# found another error, error count :  1372
# found another error, error count :  1373
# found another error, error count :  1374
# found another error, error count :  1375
# found another error, error count :  1376
# found another error, error count :  1377
# found another error, error count :  1378
# found another error, error count :  1379
# found another error, error count :  1380
# found another error, error count :  1381
# found another error, error count :  1382
# found another error, error count :  1383
# found another error, error count :  1384
# found another error, error count :  1385
# found another error, error count :  1386

# %%
from sklearn.metrics import confusion_matrix
conf = confusion_matrix(test_labels, y_pred)

print(conf)
# Out:
# [[6024  267  388   27]
#  [  23 2253   11  115]
#  [ 103   29 1628  202]
#  [   9  146   66 5297]]
